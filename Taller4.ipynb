# %%
import scikits.audiolab as audio
from scipy.fftpack import fft, fftfreq
import os
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['fft']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
system(rec -c 1 -b 16 minombre.wav)
# Out:
# ^C
# []

# %%
input_signal, sampling_rate, enc = audio.wavread("minombre.wav")

# %%
time_array = arange(0, len(input_signal)/float(sampling_rate), 1/float(sampling_rate))

# %%
plot(time_array[0:4000], input_signal[0:4000])
xlabel("time(s)", fontsize=20)
ylabel("Amplitude", fontsize=20)

# %%
print type(input_signal)
n = len(time_array) # number of point in the whole interval
f = 200.0 #  frequency in Hz
dt = 1 / (f * n/7. ) #32 samples per frequency
fft_x = fft(input_signal[:])
freq = fftfreq(n, dt)
plot(freq,abs(fft_x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-74883652c9a9> in <module>()
#       3 f = 200.0 #  frequency in Hz
#       4 dt = 1 / (f * n/7. ) #32 samples per frequency
# ----> 5 fft_x = fft(input_signal[:])
#       6 freq = fftfreq(n, dt)
#       7 #plot(freq,abs(fft_x))
#
# TypeError: 'module' object is not callable
# <type 'numpy.ndarray'>

# %%
# Out:
# 0.0

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-c794f160ef0b> in <module>()
#       4 t = linspace( 0, (n-1)*dt, n)
#       5 y = cos(2 * pi * f * t)
# ----> 6 fft(y)
#
# TypeError: 'module' object is not callable

# %%
fft?
